# %% [markdown]
# # Retirement Planner
#
# ---
#
# ## Environment Setup

# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
import os
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import alpaca_trade_api as tradeapi
# %matplotlib inline

# %%
# Set the random seed for results reproducibility (for testing purposes only)
np.random.seed(42)

# %% [markdown]
# ---
#
# ## Portfolio Planner
#
# In this activity, you will use the Alpaca API to grab historical data for a `60/40` portfolio using `SPY` to represent the stock portion and `AGG` to represent the bonds.

# %%
# Load .env enviroment variables
from dotenv import load_dotenv
load_dotenv()

# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# Create the Alpaca API object
api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %% [markdown]
# # Data Collection
#
# In this step, you will need to use the Alpaca api to fetch closing prices for the `SPY` and `AGG` tickers. Save the results as a pandas DataFrame

# %%
# Subset your tickers, then pull returns data:
# Set the ticker
ticker = ["SPY", "AGG"]

# Set timeframe to '1D'
timeframe = "1D"

# Set start and end datetimes of 1 year, between now and 365 days ago.
start_date = pd.Timestamp('2019-07-28', tz='America/New_York').isoformat()
end_date = pd.Timestamp('2020-07-27', tz='America/New_York').isoformat()

# Get 1 year's worth of historical data for SPY and AGG
df = api.get_barset(
    ticker,
    timeframe,
    limit=None,
    start=start_date,
    end=end_date,
    after=None,
    until=None,
).df

# Drop unnecessary columns
df = df.drop(
    columns=['open', 'high', 'low', 'volume'],
    level=1
)

# %%
# Display sample data
df.head()
# Out:
#                                 AGG     SPY
#                               close   close
# time
# 2019-07-29 00:00:00-04:00  111.2400  301.48
# 2019-07-30 00:00:00-04:00  111.2600  300.82
# 2019-07-31 00:00:00-04:00  111.3000  297.38
# 2019-08-01 00:00:00-04:00  111.9095  294.88
# 2019-08-02 00:00:00-04:00  111.9600  292.76

# %% [markdown]
# ---
#
# ## Monte Carlo Simulation
#
# In this step, you will run Monte Carlo Simulations for your portfolio to model portfolio performance at different retirement ages.
#
# Complete the following steps:
#
# 1. Calculate the daily returns for the SPY and AGG closing prices.
#
# 2. Calculate volatility for both the SPY and AGG closing prices.
#
# 3. Find the last day's closing price for both stocks and save those as variables
#
# 4. Run a Monte Carlo Simulation of at least `100` iterations and generate at least `30` years of closing prices
#
# **Hint:** There are `252` trading days per year, so the number of records to generate for each Monte Carlo run will be `252 days * 30 years`.

# %%
# Calculate the daily roi for the stocks
daily_returns = df.pct_change()
daily_returns.isnull().sum()
daily_returns.dropna(inplace=True)

# Display sample data
daily_returns.head()
# Out:
#                                 AGG       SPY
#                               close     close
# time
# 2019-07-30 00:00:00-04:00  0.000180 -0.002189
# 2019-07-31 00:00:00-04:00  0.000360 -0.011435
# 2019-08-01 00:00:00-04:00  0.005476 -0.008407
# 2019-08-02 00:00:00-04:00  0.000451 -0.007189
# 2019-08-05 00:00:00-04:00  0.004466 -0.029785

# %%
# Compute daily volatility

    # Average Daily Return
avg_daily_return_agg = daily_returns['AGG']['close'].mean()
avg_daily_return_spy = daily_returns['SPY']['close'].mean()

print(avg_daily_return_agg)
print(avg_daily_return_spy)

    # Standard Deviation
stdev_daily_return_agg = daily_returns['AGG']['close'].std()
stdev_daily_return_spy = daily_returns['SPY']['close'].std()

print(stdev_daily_return_agg)
print(stdev_daily_return_spy)
# Out:
# 0.0002903764687950845
# 0.0005023049275252937
# 0.005581280731956959
# 0.02117186156140736

# %%
# Save the last day's closing price

agg_last_price = df['AGG']['close'][-1]
spy_last_price = df['SPY']['close'][-1]

print(agg_last_price)
print(spy_last_price)
# Out:
# 119.18
# 323.18

# %%
# Setup the Monte Carlo Parameters
number_simulations = 500
number_records = 252 * 30
monte_carlo = pd.DataFrame()

(1 + np.random.normal(avg_daily_return_spy, stdev_daily_return_spy))
# Out:
# 1.0110186682106708

# %%
# Run the Monte Carlo Simulation

# Initialize empty DataFrame to hold simulated prices for each simulation
simulated_prices = pd.DataFrame()

# Each Simulation
for s in range(number_simulations):
    
    # Initialize simulated prices
    sim_agg_prices = [agg_last_price]
    sim_spy_prices = [spy_last_price]
    
    # Each Trading Day
    for d in range(number_records):
        
        # Calculate the simulated price using the last price within the list
        sim_agg_price = sim_agg_prices[-1] * (1 + np.random.normal(avg_daily_return_agg, stdev_daily_return_agg))
        sim_spy_price = sim_spy_prices[-1] * (1 + np.random.normal(avg_daily_return_spy, stdev_daily_return_spy))
        
        # Append the simulated price to the list
        sim_agg_prices.append(sim_agg_price)
        sim_spy_prices.append(sim_agg_price)
        
    # Append the simulated prices of each simulation to DataFrame
    simulated_prices["AGG prices"] = pd.Series(sim_agg_prices)
    simulated_prices["SPY prices"] = pd.Series(sim_spy_prices)
    
    # Calculate the daily returns of simulated prices
    simulated_daily_returns = simulated_prices.pct_change()
    
    # Set the portfolio weights (40% bonds AGG; 60% stocks SPY)
    weights = [0.40, 0.60]
    
    # Multiply weights to each columns' daily returns
    portfolio_daily_returns = simulated_daily_returns.dot(weights)
    
    # Calculate cumulative return, not just daily change
    monte_carlo[f'Sim{s+1}'] = (1 + portfolio_daily_returns.fillna(0)).cumprod()
    
# Print DataFrame results
#portfolio_daily_returns.fillna(0).cumprod()
monte_carlo.head()
# Out:
#        Sim1      Sim2      Sim3      Sim4      Sim5      Sim6      Sim7  \
# 0  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  0.620965  0.621953  0.620961  0.625138  0.629232  0.615821  0.617623
# 2  0.626423  0.624320  0.624421  0.618348  0.626798  0.616574  0.615756
# 3  0.625787  0.623663  0.623789  0.619992  0.625205  0.610866  0.618010
# 4  0.628649  0.624772  0.627585  0.622280  0.629217  0.613747  0.621696
#
#        Sim8      Sim9     Sim10  ...    Sim491    Sim492    Sim493    Sim494  \
# 0  1.000000  1.000000  1.000000  ...  1.000000  1.000000  1.000000  1.000000
# 1  0.631600  0.621396  0.617558  ...  0.622268  0.615983  0.621380  0.623015
# 2  0.628101  0.620724  0.614365  ...  0.624514  0.616097  0.621834  0.625184
# 3  0.624157  0.620467  0.619265  ...  0.624990  0.610827  0.621533  0.628037
# 4  0.619750  0.620506  0.623922  ...  0.622480  0.613568  0.621892  0.622357
#
#      Sim495    Sim496    Sim497    Sim498    Sim499    Sim500
# 0  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  0
# 7543  3.268029  5.039730  11.365737  5.171075  14.109076  2.637140  6.109099
# 7544  3.280929  5.019155  11.354926  5.199529  14.104232  2.617371  6.181766
# 7545  3.290671  5.037103  11.463913  5.179081  14.214253  2.634433  6.158535
# 7546  3.299073  5.039828  11.521809  5.167806  14.278221  2.651273  6.162985
# 7547  3.337808  5.035834  11.513852  5.163561  14.159663  2.666046  6.184163
# 7548  3.338533  5.033008  11.488624  5.128817  14.156435  2.675343  6.203943
# 7549  3.356652  4.976294  11.534529  5.103411  14.098842  2.689331  6.201234
# 7550  3.362243  4.977574  11.547655  5.174880  14.023720  2.686589  6.164632
# 7551  3.354964  5.018731  11.411353  5.153353  13.999552  2.672286  6.131735
# 7552  3.380606  4.975958  11.423247  5.097510  14.067224  2.686482  6.161190
# 7553  3.391083  4.946772  11.401155  5.062119  14.050864  2.664728  6.152016
# 7554  3.405155  4.964608  11.294877  5.080148  13.901220  2.667067  6.148537
# 7555  3.412601  4.992544  11.327307  5.106622  14.055587  2.691146  6.119644
# 7556  3.435155  4.993257  11.276878  5.085687  14.101784  2.713578  6.165502
# 7557  3.397271  4.994693  11.352725  5.087313  14.155774  2.717055  6.155596
# 7558  3.381035  5.015900  11.358001  5.087079  14.041675  2.687961  6.174204
# 7559  3.386015  5.045461  11.330949  5.082512  13.993311  2.665031  6.138940
# 7560  3.389306  5.057959  11.325285  5.079999  13.889972  2.679147  6.173314
#
# [7561 rows x 500 columns]

# %%
# Visualize the Simulation
plot_title = f"{s+1} Simulations of Cumulative Portfolio Return Trajectories Over the Next 30 years"
monte_carlo.plot(legend=None, title=plot_title)

# %%
# Select the last row for the cumulative returns (cumulative returns at 20 years)
ending_cumulative_returns = monte_carlo.iloc[-1, :]
ending_cumulative_returns.head()
# Out:
# Sim1    4.734305
# Sim2    4.294915
# Sim3    4.178790
# Sim4    3.033042
# Sim5    4.154477
# Name: 7560, dtype: float64

# %%
# Select the last row for the cumulative returns (cumulative returns at 20 years)
ending_cumulative_returns = monte_carlo.iloc[-1, :]
ending_cumulative_returns.head()
# Out:
# Sim1    4.734305
# Sim2    4.294915
# Sim3    4.178790
# Sim4    3.033042
# Sim5    4.154477
# Name: 7560, dtype: float64

# %%
# Display the 90% confidence interval for the ending returns
confidence_interval = ending_cumulative_returns.quantile(q=[0.05, 0.95])
confidence_interval
# Out:
# 0.05     2.351006
# 0.95    10.949854
# Name: 7560, dtype: float64

# %%
# Visualize the distribution of the ending returns
plt.figure()
ending_cumulative_returns.plot(kind='hist', bins=50)
plt.axvline(confidence_interval.iloc[0], color='r')
plt.axvline(confidence_interval.iloc[1], color='r')

# %% [markdown]
# ---

# %% [markdown]
# ## Retirement Analysis
#
# In this section, you will use the monte carlo model to answer the following retirement planning questions:
#
# 1. What are the expected cumulative returns at `30` years for the `10th`, `50th`, and `90th` percentiles?
#
# 2. Given an initial investment of `$20,000`, what is the expected return in dollars at the `10th`, `50th`, and `90th` percentiles?
#
# 3. Given the current projected annual income from the Plaid analysis, will a `4%` withdrawal rate meet or exceed that value at the `10th` percentile? Note: This is basically determining if retirement income is equivalent to current income.
#
# 4. How would a `50%` increase in the initial investment amount affect the `4%` retirement withdrawal? In other words, what happens if the initial investment had been bigger?

# %% [markdown]
# ### What are the expected cumulative returns at 30 years for the 10th, 50th, and 90th percentiles?

# %%
# Compute cumulative returns
confidence_interval_80 = ending_cumulative_returns.quantile(q=[0.10, 0.90])
confidence_interval_50 = ending_cumulative_returns.quantile(q=[0.50])

print(f"The expected cumulative returns after 30 years for the 10th and 90th percentiles, respectively, are {int(confidence_interval_80[.1]*100)}% and {int(confidence_interval_80[.9]*100)}%.")

print(f"The expected cumulative returns after 30 years for the 50th percentile is {int(confidence_interval_50[.5]*100)}%.")
# Out:
# The expected cumulative returns after 30 years for the 10th and 90th percentiles, respectively, are 282% and 899%.
# The expected cumulative returns after 30 years for the 50th percentile is 503%.

# %% [markdown]
# ### Given an initial investment of `$20,000`, what is the expected portfolio return in dollars at the 10th, 50th, and 90th percentiles?

# %%
# Set initial investment
investment = 20000
return_10 = confidence_interval_80[.1] * investment
return_50 = confidence_interval_50[.5] * investment
return_90 = confidence_interval_80[.9] * investment

# Compute expected portfolio return
print(f"10th Percentile: {int(return_10)}, 50th Percentile: {int(return_50)}, 90th Percentile: {int(return_90)}")
# Out:
# 10th Percentile: 56432, 50th Percentile: 100669, 90th Percentile: 179836

# %% [markdown]
# ### Given the current projected annual income from the Plaid analysis, will a 4% withdraw rate from the retirement portfolio meet or exceed that value at the 10th percentile?
#
# Note: This is effectively saying that 90% of the expected returns will be greater than the return at the 10th percentile, so this can help measure the uncertainty about having enough funds at retirement

# %%
# Set Plaid's projected income (taken from previous hw notebook)
projected_annual_income = 6085

# Calculate the 4% withdrawal for the ending return as retirement income
withdrawal_amt = int(return_10) * .04
print(withdrawal_amt)

# Determine if the retirement income meets or exceeds the current projected income
withdrawal_amt >= projected_annual_income
# Out:
# 2257.28
# False

# %% [markdown]
# ### How would a 50% increase in the initial investment amount affect the 4% retirement withdrawal?

# %%
# Re-calculate the retirement income with a 50% increase in the initial investment amount
new_investment = investment * 1.5
new_return = confidence_interval_80[.1] * new_investment
new_withdrawal_amt = int(new_return) * .04

print(new_withdrawal_amt)
new_withdrawal_amt >= projected_annual_income
# Out:
# 3385.92
# False

# %% [markdown]
# ### Optional Challenge
#
# Use the Monte Carlo data and calculate the cumulative returns at the `5%`, `50%`, and `95%` quartiles and plot this data as a line chart to see how the cumulative returns change over the life of the investment.
#
# In this section, you need to calculate and plot the cumulative returns for the median and `90%` confidence intervals. This plot shows the expected cumulative returns for any given day between the first day and the last day of investment.

# %%
# Compute projected returns

# Display sample data

# %%
# Plot the cumulative returns over time

# %%
# Compute portfolio performance over time

# Plot projected performance over time
